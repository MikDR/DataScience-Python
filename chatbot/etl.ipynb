# %%
import pandas as pd

# %%
file_path = 'csv/TMDB_movie_dataset_v11.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# ...

# %%
elimino = ["backdrop_path", "homepage", "imdb_id", "poster_path", "tagline", "spoken_languages", "keywords"]
df.drop(columns = elimino, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 2
#       1 elimino = ["backdrop_path", "homepage", "imdb_id", "poster_path", "tagline", "spoken_languages", "keywords"]
# ----> 2 df.drop(columns = elimino, inplace = True)
#
# File c:\Users\gissi\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
# ...

# %%
numero_di_righe = len(df)
print("Il dataframe ha", numero_di_righe, "righe.")

df.head()
# Out:
# Il dataframe ha 1026259 righe.
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult     budget original_language   original_title  \
# 0   825532764      148  False  160000000                en        Inception
# 1   701729206      169  False  165000000                en     Interstellar
# 2  1004558444      152  False  185000000                en  The Dark Knight
# 3  2923706026      162  False  237000000                en           Avatar
# 4  1518815515      143  False  220000000                en     The Avengers
#
# ...

# %%
df = df.dropna(subset=['title'])
df = df.dropna(subset=['original_title'])

# %%
numero_di_righe = len(df)
print("Il dataframe ha", numero_di_righe, "righe.")
# Out:
# Il dataframe ha 1026247 righe.

# %%
df.to_csv('csv/film.csv', index= False)
